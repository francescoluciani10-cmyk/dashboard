# %%
import gspread
from google.oauth2.service_account import Credentials

# === CONFIGURAZIONE ===
SHEET_ID = "1FxfkmF_3x-YzNWsCYYr1GsgHM1pq2tuPB-CWAIk-aPw"
WORKSHEET = "MarketData"  # cambia con il tab che vuoi
JSON_FILE = "google.json"

# === CONNESSIONE ===
SCOPE = [
    "https://www.googleapis.com/auth/spreadsheets",
    "https://www.googleapis.com/auth/drive"
]
creds = Credentials.from_service_account_file(JSON_FILE, scopes=SCOPE)
client = gspread.authorize(creds)

# === LETTURA DATI ===
sheet = client.open_by_key(SHEET_ID).worksheet(WORKSHEET)
data = sheet.get_all_records()
df = pd.DataFrame(data)

print("✅ Connessione riuscita! Prime righe:")
display(df.head())
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\gspread\spreadsheet.py in worksheet(self, title)
#     326         try:
# --> 327             item = finditem(
#     328                 lambda x: x["properties"]["title"] == title,
#
# ~\anaconda3\lib\site-packages\gspread\utils.py in finditem(func, seq)
#     223     """Finds and returns first item in iterable for which func(item) is True."""
# --> 224     return next(item for item in seq if func(item))
#     225
#
# StopIteration:
#
# During handling of the above exception, another exception occurred:
#
# WorksheetNotFound                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9760/290005060.py in <module>
#      17
#      18 # === LETTURA DATI ===
# ---> 19 sheet = client.open_by_key(SHEET_ID).worksheet(WORKSHEET)
#      20 data = sheet.get_all_records()
#      21 df = pd.DataFrame(data)
#
# ~\anaconda3\lib\site-packages\gspread\spreadsheet.py in worksheet(self, title)
#     331             return Worksheet(self, item["properties"], self.id, self.client)
#     332         except (StopIteration, KeyError):
# --> 333             raise WorksheetNotFound(title)
#     334
#     335     def add_worksheet(
#
# WorksheetNotFound: MarketData

# %%
# %pip install gspread google-auth pandas
# Out:
# Requirement already satisfied: gspread in c:\users\utente\anaconda3\lib\site-packages (6.2.1)
# Requirement already satisfied: google-auth in c:\users\utente\anaconda3\lib\site-packages (2.41.1)
# Requirement already satisfied: pandas in c:\users\utente\anaconda3\lib\site-packages (1.3.4)
# Requirement already satisfied: google-auth-oauthlib>=0.4.1 in c:\users\utente\anaconda3\lib\site-packages (from gspread) (1.2.3)
# Requirement already satisfied: cachetools<7.0,>=2.0.0 in c:\users\utente\anaconda3\lib\site-packages (from google-auth) (6.2.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\utente\anaconda3\lib\site-packages (from google-auth) (4.9.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\utente\anaconda3\lib\site-packages (from google-auth) (0.4.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\utente\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\utente\anaconda3\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\utente\anaconda3\lib\site-packages (from pandas) (1.20.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\utente\anaconda3\lib\site-packages (from google-auth-oauthlib>=0.4.1->gspread) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\utente\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth) (0.6.1)
# Requirement already satisfied: six>=1.5 in c:\users\utente\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.16.0)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\utente\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.3.1)
# Requirement already satisfied: requests>=2.0.0 in c:\users\utente\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.32.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\utente\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\utente\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (1.26.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\utente\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\utente\anaconda3\lib\site-packages (from requests>=2.0.0->requests-oauthlib>=0.7.0->google-auth-oauthlib>=0.4.1->gspread) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import gspread
from google.oauth2.service_account import Credentials
import pandas as pd

# === CONFIGURAZIONE ===
SHEET_ID = "1FxfkmF_3x-YzNWsCYYr1GsgHM1pq2tuPB-CWAIk-aPw"
WORKSHEET = "Europe Countries GDP"  # cambia con il tab che vuoi
JSON_FILE = "google.json"

# === CONNESSIONE ===
SCOPE = [
    "https://www.googleapis.com/auth/spreadsheets",
    "https://www.googleapis.com/auth/drive"
]
creds = Credentials.from_service_account_file(JSON_FILE, scopes=SCOPE)
client = gspread.authorize(creds)

# === LETTURA DATI ===
sheet = client.open_by_key(SHEET_ID).worksheet(WORKSHEET)
data = sheet.get_all_records()
df = pd.DataFrame(data)

print("✅ Connessione riuscita! Prime righe:")
display(df.head())
# Out:
# ✅ Connessione riuscita! Prime righe:
#          Euro area   Austria   Belgium   Croatia    Cyprus   Estonia  \
# 0  1999   2.907059  3.658583  3.542741 -0.848694  4.997955 -0.510547
# 1  2000   4.034347  3.411958  3.716681  2.945253  5.965304  9.863550
# 2  2001   2.157627  1.286858  1.099612  3.111235  3.952563  5.852184
# 3  2002   0.930736  1.479346  1.706894  5.803328  3.722975  6.987045
# 4  2003   0.739452  1.105328  1.037967  5.568373  2.623300  7.805903
#
#     Finland    France   Germany  ...  Slovakia  Slovenia     Spain  Bulgaria  \
# 0  4.389933  3.260717  1.990435  ... -0.473261  5.267922  4.408893 -10.96837
# 1  5.752541  4.363915  3.106803  ...  0.789224  3.497917  5.200574  11.48665
# 2  2.641424  1.846577  1.752347  ...  2.925161  2.828504  3.919119   4.48211
# 3  1.687326  1.118896 -0.189017  ...  4.417253  3.282693  2.755515   5.74774
# 4  2.011257  0.994613 -0.544085  ...  4.856699  3.194905  2.939270    5.7323
#
#    Czechia  Denmark  Hungary   Poland  Romania   Sweden
# 0  2.61144  3.50999  4.20654  6.60397 -6.79962  3.88022
# 1  3.93845  3.65312  4.66541  4.05883  4.33847  4.36828
# 2  2.53435  0.24662   3.1577 -0.27796  8.72223  0.89277
# 3  1.42053 -0.32024  5.01875  2.78521  3.33665  1.93498
# 4  3.84671  1.74449  3.95938  4.22216  1.28685  2.57208
#
# [5 rows x 29 columns]
